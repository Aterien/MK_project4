# %% [markdown]
# # Poprawiony mały projekt 1

# %%
import os

from src.analiza import *
from src.wczytaj_wyczysc import *
from src.wizualizacja import *

# %%
gios_archive_url = "https://powietrze.gios.gov.pl/pjp/archives/downloadFile/"
gios_url_ids = {
    2015: '236',
    2018: '603',
    2021: '486',
    2024: '582'
}
gios_pm25_file = {
    2015: '2015_PM25_1g.xlsx',
    2018: '2018_PM25_1g.xlsx',
    2021: '2021_PM25_1g.xlsx',
    2024: '2024_PM25_1g.xlsx'
}
metadata_url_id = "622"

# %% [markdown]
# ## Zadanie 1: Wczytywanie i czyszczenie danych

# %%
metadata = download_metadata(gios_archive_url=gios_archive_url,metadata_url_id=metadata_url_id)

# %%
#Wczytywanie
raw_data = {}
for rok in [2015, 2018, 2021, 2024]:
    raw_dataset = download_gios_archive(gios_archive_url=gios_archive_url, gios_id=gios_url_ids[rok], filename=gios_pm25_file[rok])
    raw_data[rok] = ujednolic_dane(raw_dataset,metadata)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:7588: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:7588: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:7588: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)

# %%
data = df_gotowy(list(raw_data.values()),metadata) #sprowadzam slownik raw_data {rok:df} do listy [df].

# %%
raw_data[2015].head()
# Out:
# 0                       DsJelGorOgin DsWrocAlWisn DsWrocWybCon KpBydPlPozna  \
# Data poboru danych
# 2015-01-01 01:00:00.000      151.112           78           50         29.2
# 2015-01-01 02:00:00.000      262.566           42      33.8244         27.1
# 2015-01-01 03:00:00.005       222.83           27      28.7215          7.9
# 2015-01-01 04:00:00.010      210.767           24      20.6891          7.1
# 2015-01-01 05:00:00.015      191.211           22      22.5335          9.2
#
# 0                       KpBydWarszaw KpToruDziewu LbLubObywate LdLodzCzerni  \
# Data poboru danych
# 2015-01-01 01:00:00.000         95.5       27.352      71.1012        59.73
# 2015-01-01 02:00:00.000         86.1      78.0064      95.2582       185.92
# 2015-01-01 03:00:00.005         23.8      21.1056      49.5078        54.25
# 2015-01-01 04:00:00.010         15.9      16.9088      60.8468        50.15
# 2015-01-01 05:00:00.015           15      16.8112      49.3106        39.17
#
# 0                       LdLodzGdansk LdZgieMielcz  ... SkMalo11List  \
# Data poboru danych                                 ...
# 2015-01-01 01:00:00.000          NaN    58.690689  ...         39.6
# 2015-01-01 02:00:00.000          NaN    44.501255  ...         33.6
# 2015-01-01 03:00:00.005          NaN    24.163937  ...           35
# 2015-01-01 04:00:00.010          NaN    19.516039  ...         34.8
# 2015-01-01 05:00:00.015          NaN    16.850332  ...         35.8
#
# 0                       SkPolaRuszcz SlGliwicMewy SlKatoKossut SlZlotPotLes  \
# Data poboru danych
# 2015-01-01 01:00:00.000         72.4       77.828       51.389      49.9464
# 2015-01-01 02:00:00.000         57.2      50.0552       37.709      45.6291
# 2015-01-01 03:00:00.005         41.9      52.0277       41.984      49.2093
# 2015-01-01 04:00:00.010         36.7      49.1084       45.404       53.316
# 2015-01-01 05:00:00.015           36      44.0588       36.854      51.5259
#
# 0                       WmOlsPuszkin WpKaliSawick WpPoznPolank ZpSzczAndr01  \
# Data poboru danych
# 2015-01-01 01:00:00.000    44.060833         25.5      24.4768          NaN
# 2015-01-01 02:00:00.000    49.943329         32.5        29.86      81.8501
# 2015-01-01 03:00:00.005    20.688448         24.3      29.3744      25.7333
# 2015-01-01 04:00:00.010    17.437717         24.4        28.34       18.624
# 2015-01-01 05:00:00.015    15.532262           25      25.2286      17.6545
#
# 0                       ZpSzczPils02
# Data poboru danych
# 2015-01-01 01:00:00.000          NaN
# 2015-01-01 02:00:00.000      215.379
# 2015-01-01 03:00:00.005      27.7458
# 2015-01-01 04:00:00.010      26.5201
# 2015-01-01 05:00:00.015      31.0393
#
# [5 rows x 42 columns]
